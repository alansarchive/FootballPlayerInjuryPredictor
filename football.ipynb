# %% [markdown]
# # Load Data

# %%
# !pip install kagglehub
import kagglehub
# Out:
# Collecting kagglehub
#   Using cached kagglehub-0.3.13-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: packaging in c:\users\alana\anaconda3\lib\site-packages (from kagglehub) (24.1)
# Requirement already satisfied: pyyaml in c:\users\alana\anaconda3\lib\site-packages (from kagglehub) (6.0.1)
# Requirement already satisfied: requests in c:\users\alana\anaconda3\lib\site-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\alana\anaconda3\lib\site-packages (from kagglehub) (4.66.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\alana\anaconda3\lib\site-packages (from requests->kagglehub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alana\anaconda3\lib\site-packages (from requests->kagglehub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alana\anaconda3\lib\site-packages (from requests->kagglehub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alana\anaconda3\lib\site-packages (from requests->kagglehub) (2025.4.26)
# Requirement already satisfied: colorama in c:\users\alana\anaconda3\lib\site-packages (from tqdm->kagglehub) (0.4.6)
# Using cached kagglehub-0.3.13-py3-none-any.whl (68 kB)
# Installing collected packages: kagglehub
# Successfully installed kagglehub-0.3.13

# %%
path = kagglehub.dataset_download("yuanchunhong/university-football-injury-prediction-dataset")
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/yuanchunhong/university-football-injury-prediction-dataset?dataset_version_number=2...
# 100%|██████████| 83.9k/83.9k [00:00<00:00, 1.17MB/s]
# Extracting files...

# %%
import os
import pandas as pd
print(("files in directory:", os.listdir(path)))
# Out:
# ('files in directory:', ['data.csv'])

# %%
csv_file = os.path.join(path, "data.csv")
data = pd.read_csv(csv_file)

# %%
data.head(10)
# Out:
#    Age  Height_cm  Weight_kg    Position  Training_Hours_Per_Week  \
# 0   22        173         64  Midfielder                11.575308
# 1   18        170         67  Midfielder                12.275869
# 2   22        186         75     Forward                12.254896
# 3   20        172         62    Defender                 9.006678
# 4   18        172         94  Midfielder                12.683668
# 5   23        189         89  Goalkeeper                10.262987
# 6   22        189         71  Midfielder                 8.069288
# 7   23        184         75  Goalkeeper                 6.407939
# 8   22        174         71  Midfielder                10.554931
# 9   23        185         76  Midfielder                11.899732
#
#    Matches_Played_Past_Season  Previous_Injury_Count  Knee_Strength_Score  \
# 0                          36                      1            77.460279
# 1                          37                      2            72.634442
# 2                          12                      2            77.064490
# 3                          11                      1            82.810232
# 4                          10                      2            76.772859
# 5                          31                      2            78.450720
# 6                           5                      4            63.045009
# 7                          26                      0            77.566677
# 8                          23                      0            78.877905
# 9                          22                      0            83.194761
#
#    Hamstring_Flexibility  Reaction_Time_ms  Balance_Test_Score  \
# 0              79.115738        284.487853           91.212476
# 1              82.541688        250.579249           87.294078
# 2              75.943631        269.119918           83.440688
# 3              73.878324        226.376412           87.591894
# 4              76.653043        229.021042           83.125161
# 5              80.927984        265.801623           81.106339
# 6              75.032030        269.099907           76.787369
# 7              76.947213        226.966431           93.317382
# 8              89.584501        240.745054           80.898575
# 9              82.244364        259.628161           89.077577
#
#    Sprint_Speed_10m_s  Agility_Score  Sleep_Hours_Per_Night  \
# 0            5.874630      77.599705               8.238293
# 1            5.796269      94.418987               8.983737
# 2            5.731209      70.179176               7.229193
# 3            6.220212      83.473824               7.681029
# 4            5.385958      87.037256               6.728091
# 5            6.354870      86.418954               8.538027
# 6            6.458297      65.179995               7.339327
# 7            6.161460      79.260417               8.072895
# 8            6.199281      77.152290               7.661190
# 9            6.206694      90.396480               6.035505
#
#    Stress_Level_Score  Nutrition_Quality_Score  Warmup_Routine_Adherence  \
# 0           46.616415                81.472206                         1
# 1           49.368037                81.056677                         1
# 2           43.132808                64.877457                         0
# 3           51.528529                89.824744                         1
# 4           52.379718                71.569197                         0
# 5           39.929697                74.982476                         1
# 6           75.039112                65.790192                         0
# 7           25.783371                89.782578                         0
# 8           52.581600                78.587201                         1
# 9           55.049722                83.947949                         1
#
#    Injury_Next_Season        BMI
# 0                   0  21.383942
# 1                   0  23.183391
# 2                   1  21.678807
# 3                   0  20.957274
# 4                   1  31.773932
# 5                   0  24.915316
# 6                   1  19.876263
# 7                   0  22.152647
# 8                   0  23.450918
# 9                   0  22.205990

# %%
data.shape
# Out:
# (800, 19)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         800 non-null    int64
#  1   Height_cm                   800 non-null    int64
#  2   Weight_kg                   800 non-null    int64
#  3   Position                    800 non-null    object
#  4   Training_Hours_Per_Week     800 non-null    float64
#  5   Matches_Played_Past_Season  800 non-null    int64
#  6   Previous_Injury_Count       800 non-null    int64
#  7   Knee_Strength_Score         800 non-null    float64
#  8   Hamstring_Flexibility       800 non-null    float64
#  9   Reaction_Time_ms            800 non-null    float64
#  10  Balance_Test_Score          800 non-null    float64
#  11  Sprint_Speed_10m_s          800 non-null    float64
#  12  Agility_Score               800 non-null    float64
#  13  Sleep_Hours_Per_Night       800 non-null    float64
#  14  Stress_Level_Score          800 non-null    float64
#  15  Nutrition_Quality_Score     800 non-null    float64
#  16  Warmup_Routine_Adherence    800 non-null    int64
#  17  Injury_Next_Season          800 non-null    int64
#  18  BMI                         800 non-null    float64
# dtypes: float64(11), int64(7), object(1)
# memory usage: 118.9+ KB

# %% [markdown]
# # Data Preprocessing

# %%
data['Position'] = data['Position'].astype('category')

# %%
data.describe().T
# Out:
#                             count        mean        std         min  \
# Age                         800.0   21.135000   1.991037   18.000000
# Height_cm                   800.0  177.407500   7.148974  154.000000
# Weight_kg                   800.0   73.235000   9.929276   45.000000
# Training_Hours_Per_Week     800.0    9.951150   2.610395    5.000000
# Matches_Played_Past_Season  800.0   22.332500  10.311516    5.000000
# Previous_Injury_Count       800.0    1.536250   1.292584    0.000000
# Knee_Strength_Score         800.0   74.933249   6.672704   52.391351
# Hamstring_Flexibility       800.0   79.154123   6.782332   58.180381
# Reaction_Time_ms            800.0  249.423244  22.532387  180.000000
# Balance_Test_Score          800.0   83.832337   6.931657   60.059484
# Sprint_Speed_10m_s          800.0    5.949025   0.329133    4.862435
# Agility_Score               800.0   78.341311   8.775418   50.000000
# Sleep_Hours_Per_Night       800.0    7.417124   0.793183    5.000000
# Stress_Level_Score          800.0   54.039342  11.421143   21.561186
# Nutrition_Quality_Score     800.0   74.382174   9.324899   50.000000
# Warmup_Routine_Adherence    800.0    0.597500   0.490708    0.000000
# Injury_Next_Season          800.0    0.500000   0.500313    0.000000
# BMI                         800.0   23.377364   3.673279   14.346326
#
#                                    25%         50%         75%         max
# Age                          19.000000   21.000000   23.000000   24.000000
# Height_cm                   173.000000  177.000000  182.000000  200.000000
# Weight_kg                    66.000000   73.000000   80.000000  105.000000
# Training_Hours_Per_Week       8.127151    9.895710   11.535140   18.866608
# Matches_Played_Past_Season   13.000000   22.000000   32.000000   39.000000
# Previous_Injury_Count         1.000000    1.000000    2.000000    8.000000
# Knee_Strength_Score          70.432656   74.997933   79.632391   93.900051
# Hamstring_Flexibility        74.495959   79.187909   83.813179  100.000000
# Reaction_Time_ms            234.089585  249.127328  265.105082  306.730851
# Balance_Test_Score           79.044910   84.156236   88.877902  100.000000
# Sprint_Speed_10m_s            5.732552    5.937692    6.159205    6.898228
# Agility_Score                72.675392   78.340973   84.093489  100.000000
# Sleep_Hours_Per_Night         6.850062    7.424618    7.988100    9.860553
# Stress_Level_Score           45.775371   54.047208   61.910804   87.065007
# Nutrition_Quality_Score      67.809084   74.363878   80.502613  100.000000
# Warmup_Routine_Adherence      0.000000    1.000000    1.000000    1.000000
# Injury_Next_Season            0.000000    0.500000    1.000000    1.000000
# BMI                          20.786644   23.130560   26.024182   36.262439

# %%
injury_data = data.groupby("Injury_Next_Season").mean(numeric_only=True).round(2)
injury_data
# Out:
#                       Age  Height_cm  Weight_kg  Training_Hours_Per_Week  \
# Injury_Next_Season
# 0                   21.09     177.80      73.03                     9.86
# 1                   21.18     177.02      73.44                    10.04
#
#                     Matches_Played_Past_Season  Previous_Injury_Count  \
# Injury_Next_Season
# 0                                        22.78                   1.04
# 1                                        21.88                   2.03
#
#                     Knee_Strength_Score  Hamstring_Flexibility  \
# Injury_Next_Season
# 0                                 77.96                  82.21
# 1                                 71.90                  76.10
#
#                     Reaction_Time_ms  Balance_Test_Score  Sprint_Speed_10m_s  \
# Injury_Next_Season
# 0                             238.82               87.26                6.10
# 1                             260.03               80.40                5.79
#
#                     Agility_Score  Sleep_Hours_Per_Night  Stress_Level_Score  \
# Injury_Next_Season
# 0                           81.79                   7.82               47.99
# 1                           74.89                   7.01               60.09
#
#                     Nutrition_Quality_Score  Warmup_Routine_Adherence    BMI
# Injury_Next_Season
# 0                                     78.23                      0.73  23.20
# 1                                     70.54                      0.47  23.55

# %%
import seaborn as sns
sns.pairplot(
    data[["Sleep_Hours_Per_Night", "Nutrition_Quality_Score", "Stress_Level_Score", "Injury_Next_Season", "Knee_Strength_Score"]],
    hue = "Injury_Next_Season",
    height = 4,
    palette = "Set1"
)

# %%
sns.heatmap(
    data[["Sleep_Hours_Per_Night", "Nutrition_Quality_Score", "Stress_Level_Score", "Injury_Next_Season", "Knee_Strength_Score"]].corr(),
    annot= True)
# Out:
# <Axes: >

# %%
data = pd.get_dummies(data)

# %% [markdown]
# # Logistic Regression Model Build

# %%
data.columns
# Out:
# Index(['Age', 'Height_cm', 'Weight_kg', 'Training_Hours_Per_Week',
#        'Matches_Played_Past_Season', 'Previous_Injury_Count',
#        'Knee_Strength_Score', 'Hamstring_Flexibility', 'Reaction_Time_ms',
#        'Balance_Test_Score', 'Sprint_Speed_10m_s', 'Agility_Score',
#        'Sleep_Hours_Per_Night', 'Stress_Level_Score',
#        'Nutrition_Quality_Score', 'Warmup_Routine_Adherence',
#        'Injury_Next_Season', 'BMI', 'Position_Defender', 'Position_Forward',
#        'Position_Goalkeeper', 'Position_Midfielder'],
#       dtype='object')

# %%
y = data["Injury_Next_Season"]

# %%
x = data.drop("Injury_Next_Season", axis = 1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x, y ,
    train_size = 0.8, 
    random_state = 1
)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression(penalty=None, solver = 'newton-cg', max_iter = 150)

# %%
lr.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=150, penalty=None, solver='newton-cg')

# %% [markdown]
# ### Model accuracy score

# %%
round(lr.score(x_train, y_train), 3)
# Out:
# 0.964

# %%
round(lr.score(x_test, y_test), 3)
# Out:
# 0.931

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

pred = lr.predict(x_test)
ypred = list(map(round, pred))
cm = confusion_matrix(y_test, ypred)

disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

# %% [markdown]
# # Model Prediction

# %%
data_new = x_train[:5]

# %%
lr.predict(data_new)
# Out:
# array([1, 0, 0, 1, 0], dtype=int64)

# %%
y_train[:5]
# Out:
# 797    1
# 411    0
# 0      0
# 318    1
# 555    0
# Name: Injury_Next_Season, dtype: int64
